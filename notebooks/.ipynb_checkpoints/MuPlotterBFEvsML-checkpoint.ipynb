# %%
#!/usr/bin/Rscript

if (!require("pacman")) install.packages("pacman")
pacman::p_load(ggplot2, sqldf, tidyr, stringr, dplyr, doBy, plyr)
RESEARCH_HOME = Sys.getenv(c("RESEARCH_HOME"))
PATH = "Scripts/Python/data/"
SAVE_PDF = F
W = 6
H = 6
muDefault      = 5
deltaDefault   = 6
epsilonDefault = 100

ml  = read.csv(paste0(RESEARCH_HOME, PATH, 'ml_mu.csv'), header = F, sep = ";")
bfe = read.csv(paste0(RESEARCH_HOME, PATH, 'bfe_mu.csv'), header = F, sep = ";")

data = rbind(ml, bfe)
names(data) = c("runID", "Method", "Epsilon", "Mu", "Delta", "Time")
data$Epsilon = as.numeric(as.character(data$Epsilon))
data$Mu      = as.numeric(as.character(data$Mu))
data$Delta   = as.numeric(as.character(data$Delta))
data$Time    = as.numeric(as.character(data$Time))

# %%
head(data[order(data$Mu), ])
nrow(data)
# Out:
#    runID Method    Epsilon Mu Delta Time
# 1   0    MergeLast 100     4  6      864.323
# 10  9    MergeLast 100     4  6      884.229
# 11 10    MergeLast 100     4  6      862.928
# 20 19    MergeLast 100     4  6      889.162
# 21 20    MergeLast 100     4  6      888.200
# 26  5    bfe       100     4  6     1191.880
# [1] 40

# %%
df = summaryBy(data=data, Time ~ Epsilon + Mu + Delta + Method, FUN = function(x){ c(m=mean(x),s=sd(x))})
df
# Out:
#    Epsilon Mu Delta Method    Time.m    Time.s
# 1  100     4  6     MergeLast  877.7684 13.051705
# 2  100     4  6     bfe       1194.9967  3.006798
# 3  100     5  6     MergeLast  760.8606 17.403552
# 4  100     5  6     bfe        709.2300 10.108368
# 5  100     6  6     MergeLast 1454.2506 91.382032
# 6  100     6  6     bfe        479.9000 13.280723
# 7  100     7  6     MergeLast  989.6596 37.391802
# 8  100     7  6     bfe        348.5767 10.539404
# 9  100     8  6     MergeLast  991.7336 66.983502
# 10 100     8  6     bfe        268.7833  5.534928

# %%
title = "Execution time by Mu"
g = ggplot(data=df, aes(x=factor(Mu), y=Time.m, fill=Method, ymin = Time.m-Time.s, ymax = Time.m+Time.s)) +
  geom_bar(stat="identity", position=position_dodge(width = 0.75),width = 0.75) +
  geom_pointrange(position=position_dodge(width = 0.75)) +
  labs(title=title, y="Time(s)", x=expression(paste(mu,"(objects)"))) 
plot(g)
# Out:
# plot without title

# %%
st = read.csv(paste0(RESEARCH_HOME, PATH, 'ml_mu_stages.csv'), header = F, sep = ";")

names(st)  = c("runID", "n", "Method", "Epsilon", "Mu", "Delta", "Stage", "Time")
st$Epsilon = as.numeric(as.character(st$Epsilon))
st$Mu      = as.numeric(as.character(st$Mu))
st$Delta   = as.numeric(as.character(st$Delta))
st$Time    = as.numeric(as.character(st$Time))
st = st[, c("runID", "Stage", "Epsilon", "Mu", "Delta", "Time")]

# %%
st_s = summaryBy(data=st, Time ~ Epsilon + Mu + Delta + Stage, FUN = function(x){ c(m=mean(x),s=sd(x))})
st_s
# Out:
#    Epsilon Mu Delta Stage                        Time.m      Time.s
# 1  100     4  6     0.Reporting locations           5.046667  0.2544563
# 2  100     4  6     1.Set of disks for t_i         36.118000 23.0105210
# 3  100     4  6     2.Set of disks for t_i+delta   60.814000 22.7158710
# 4  100     4  6     3.Joining timestams            21.235333  1.5319060
# 5  100     4  6     4.Checking internals           14.781667  1.0261279
# 6  100     4  6     Running MergeLast             877.768000 13.0515965
# 7  100     5  6     0.Reporting locations           5.034833  0.2320176
# 8  100     5  6     1.Set of disks for t_i         33.273333 17.6678610
# 9  100     5  6     2.Set of disks for t_i+delta   48.263667  9.1466155
# 10 100     5  6     3.Joining timestams            17.808000  1.3943912
# 11 100     5  6     4.Checking internals           14.216667  1.1028531
# 12 100     5  6     Running MergeLast             760.860000 17.4005488
# 13 100     6  6     0.Reporting locations           5.148167  0.2822998
# 14 100     6  6     1.Set of disks for t_i        120.837667 95.6861454
# 15 100     6  6     2.Set of disks for t_i+delta   77.437000 26.0327523
# 16 100     6  6     3.Joining timestams            16.239667  1.0251946
# 17 100     6  6     4.Checking internals           14.436667  1.2772555
# 18 100     6  6     Running MergeLast            1454.252000 91.3829920
# 19 100     7  6     0.Reporting locations           5.042667  0.3063225
# 20 100     7  6     1.Set of disks for t_i         56.695000 38.6907296
# 21 100     7  6     2.Set of disks for t_i+delta   61.080667 23.4987728
# 22 100     7  6     3.Joining timestams            20.015000  1.3161143
# 23 100     7  6     4.Checking internals           13.990333  1.3410559
# 24 100     7  6     Running MergeLast             989.660000 37.3925761
# 25 100     8  6     0.Reporting locations           4.929333  0.2971210
# 26 100     8  6     1.Set of disks for t_i         61.574333 52.8072386
# 27 100     8  6     2.Set of disks for t_i+delta   61.775000 14.6131770
# 28 100     8  6     3.Joining timestams            15.073333  1.0572845
# 29 100     8  6     4.Checking internals           13.887333  1.3435078
# 30 100     8  6     Running MergeLast             991.736000 66.9819280

# %%
title = "Execution time by Mu"
g = ggplot(data=st_s, aes(x=factor(Mu), y=Time.m, fill=Stage, ymin = Time.m-Time.s, ymax = Time.m+Time.s)) +
  geom_bar(stat="identity", position=position_dodge(width = 0.75),width = 0.75) +
  geom_pointrange(position=position_dodge(width = 0.75)) +
  labs(title=title, y="Time(s)", x=expression(paste(mu,"(objects)"))) 
plot(g)
# Out:
# plot without title

# %%
mdf = read.csv(paste0(RESEARCH_HOME, PATH, 'ml_mu_mdf.csv'), header = F, sep = ";")

names(mdf)  = c("mdfID", "n", "runID", "Stage", "Epsilon", "Mu", "Delta", "Time", "Load", "Timestamp")
mdf$Epsilon   = as.numeric(as.character(mdf$Epsilon))
mdf$Mu        = as.numeric(as.character(mdf$Mu))
mdf$Delta     = as.numeric(as.character(mdf$Delta))
mdf$Time      = as.numeric(as.character(mdf$Time))
mdf$Load      = as.numeric(as.character(mdf$Load))
mdf$Timestamp = as.numeric(as.character(mdf$Timestamp))

mdf_s = summaryBy(data=mdf, Time ~ Epsilon + Mu + Delta + Stage, FUN = function(x){ c(m=mean(x),s=sd(x))})
mdf_s
# Out:
#    Epsilon Mu Delta Stage                                Time.m     Time.s
# 1  100     4  6     A.Indexing points...                  6.6681455  1.45715815
# 2  100     4  6     B.Getting pairs...                    9.1164545  2.53361606
# 3  100     4  6     C.Computing centers...                1.6045273  0.28322951
# 4  100     4  6     D.Indexing centers...                 1.4286545  0.17531846
# 5  100     4  6     E.Getting disks...                    7.4998545  1.16958255
# 6  100     4  6     F.Filtering less-than-mu disks...     0.7684909  0.19432856
# 7  100     4  6     G.Prunning duplicate candidates...    3.2465455  0.57420015
# 8  100     4  6     H.Indexing candidates...              3.7046727  0.61862081
# 9  100     4  6     I.Getting expansions...               0.3363636  0.09391019
# 10 100     4  6     J.Finding maximal disks...           19.0960727 19.85657921
# 11 100     4  6     K.Prunning duplicates and subsets...  2.0638727  0.36367680
# 12 100     5  6     A.Indexing points...                  6.7035636  1.43926937
# 13 100     5  6     B.Getting pairs...                    9.1312727  2.56032562
# 14 100     5  6     C.Computing centers...                1.6117273  0.28851327
# 15 100     5  6     D.Indexing centers...                 1.3931091  0.16890471
# 16 100     5  6     E.Getting disks...                    7.5736364  1.13671314
# 17 100     5  6     F.Filtering less-than-mu disks...     0.6803636  0.16665582
# 18 100     5  6     G.Prunning duplicate candidates...    3.0280000  0.48359755
# 19 100     5  6     H.Indexing candidates...              3.4630364  0.52170820
# 20 100     5  6     I.Getting expansions...               0.3403455  0.09418446
# 21 100     5  6     J.Finding maximal disks...           10.9682182  8.97179104
# 22 100     5  6     K.Prunning duplicates and subsets...  2.0318727  0.35692582
# 23 100     6  6     A.Indexing points...                  6.6965818  1.43079847
# 24 100     6  6     B.Getting pairs...                    9.1885091  2.57819237
# 25 100     6  6     C.Computing centers...                1.6104182  0.29682222
# 26 100     6  6     D.Indexing centers...                 1.3910909  0.17617660
# 27 100     6  6     E.Getting disks...                    7.4619636  1.14595774
# 28 100     6  6     F.Filtering less-than-mu disks...     0.6085818  0.15420353
# 29 100     6  6     G.Prunning duplicate candidates...    2.7850909  0.56718712
# 30 100     6  6     H.Indexing candidates...              3.1931091  0.59657230
# 31 100     6  6     I.Getting expansions...               0.3049636  0.06555093
# 32 100     6  6     J.Finding maximal disks...           75.1527818 71.67234912
# 33 100     6  6     K.Prunning duplicates and subsets...  1.9869818  0.34207691
# 34 100     7  6     A.Indexing points...                  6.5386727  1.41421811
# 35 100     7  6     B.Getting pairs...                    8.9379455  2.46321627
# 36 100     7  6     C.Computing centers...                1.6032909  0.30973768
# 37 100     7  6     D.Indexing centers...                 1.3896909  0.18124527
# 38 100     7  6     E.Getting disks...                    7.4879636  1.14159975
# 39 100     7  6     F.Filtering less-than-mu disks...     0.5853273  0.15745276
# 40 100     7  6     G.Prunning duplicate candidates...    2.6103636  0.40408779
# 41 100     7  6     H.Indexing candidates...              3.0030000  0.42955222
# 42 100     7  6     I.Getting expansions...               0.3067455  0.06736172
# 43 100     7  6     J.Finding maximal disks...           31.8565091 29.68785971
# 44 100     7  6     K.Prunning duplicates and subsets...  1.9567091  0.32932786
# 45 100     8  6     A.Indexing points...                  6.6301455  1.40897021
# 46 100     8  6     B.Getting pairs...                    9.0925455  2.50771944
# 47 100     8  6     C.Computing centers...                1.6123455  0.27794892
# 48 100     8  6     D.Indexing centers...                 1.3910909  0.17361988
# 49 100     8  6     E.Getting disks...                    7.5009455  1.18209399
# 50 100     8  6     F.Filtering less-than-mu disks...     0.5787273  0.12371120
# 51 100     8  6     G.Prunning duplicate candidates...    2.5974909  0.50159870
# 52 100     8  6     H.Indexing candidates...              2.9930364  0.51778603
# 53 100     8  6     I.Getting expansions...               0.3044909  0.06283042
# 54 100     8  6     J.Finding maximal disks...           34.6012545 36.07908253
# 55 100     8  6     K.Prunning duplicates and subsets...  2.0228182  0.40611105

# %%
title = "Execution time by Epsilon"
g = ggplot(data=mdf_s, aes(x=factor(Epsilon), y=Time.m, fill=Stage, ymin = Time.m-Time.s, ymax = Time.m+Time.s)) +
  geom_bar(stat="identity", position=position_dodge(width = 0.75),width = 0.75) +
  geom_pointrange(position=position_dodge(width = 0.75)) +
  labs(title=title, y="Time(s)", x=expression(paste(epsilon,"(mts)"))) 
plot(g)
# Out:
# plot without title

# %%
mdf_110 = mdf[mdf$Epsilon == 110 & (mdf$Stage == "H.Indexing candidates..." | mdf$Stage == "J.Finding maximal disks..."), ]
mdf_110

data = sqldf("SELECT mdfID, Timestamp, MAX(Time) AS Time, MAX(Load) AS Load FROM mdf_110 GROUP BY mdfID, Timestamp")
# Out:
#      mdfID n    runID Stage                      Epsilon Mu Delta Time
# 371  33     799 3     H.Indexing candidates...   110     5  6        3.869
# 373  33     801 3     J.Finding maximal disks... 110     5  6       46.072
# 382  34     816 3     H.Indexing candidates...   110     5  6        3.957
# 384  34     818 3     J.Finding maximal disks... 110     5  6      105.520
# 393  35     839 3     H.Indexing candidates...   110     5  6        2.942
# 395  35     841 3     J.Finding maximal disks... 110     5  6       50.596
# 404  36     856 3     H.Indexing candidates...   110     5  6        3.429
# 406  36     858 3     J.Finding maximal disks... 110     5  6       38.013
# 415  37     879 3     H.Indexing candidates...   110     5  6        2.248
# 417  37     881 3     J.Finding maximal disks... 110     5  6      109.573
# 426  38     896 3     H.Indexing candidates...   110     5  6        3.055
# 428  38     898 3     J.Finding maximal disks... 110     5  6       49.281
# 437  39     919 3     H.Indexing candidates...   110     5  6        3.143
# 439  39     921 3     J.Finding maximal disks... 110     5  6      105.985
# 448  40     936 3     H.Indexing candidates...   110     5  6        3.170
# 450  40     938 3     J.Finding maximal disks... 110     5  6       30.801
# 459  41     959 3     H.Indexing candidates...   110     5  6        3.483
# 461  41     961 3     J.Finding maximal disks... 110     5  6     1795.624
# 470  42     976 3     H.Indexing candidates...   110     5  6        4.627
# 472  42     978 3     J.Finding maximal disks... 110     5  6       50.021
# 481  43    1001 3     H.Indexing candidates...   110     5  6        3.302
# 483  43    1003 3     J.Finding maximal disks... 110     5  6       31.996
# 976  88    2084 8     H.Indexing candidates...   110     5  6        4.189
# 978  88    2086 8     J.Finding maximal disks... 110     5  6       54.306
# 987  89    2101 8     H.Indexing candidates...   110     5  6        3.600
# 989  89    2103 8     J.Finding maximal disks... 110     5  6       40.114
# 998  90    2124 8     H.Indexing candidates...   110     5  6        2.735
# 1000 90    2126 8     J.Finding maximal disks... 110     5  6       47.883
# 1009 91    2141 8     H.Indexing candidates...   110     5  6        3.485
# 1011 91    2143 8     J.Finding maximal disks... 110     5  6       43.987
# ⋮    ⋮     ⋮    ⋮     ⋮                          ⋮       ⋮  ⋮     ⋮
# 1658 150   3506 13    H.Indexing candidates...   110     5  6        2.907
# 1660 150   3508 13    J.Finding maximal disks... 110     5  6       27.390
# 1669 151   3529 13    H.Indexing candidates...   110     5  6        4.190
# 1671 151   3531 13    J.Finding maximal disks... 110     5  6     1544.220
# 1680 152   3546 13    H.Indexing candidates...   110     5  6        3.506
# 1682 152   3548 13    J.Finding maximal disks... 110     5  6       61.232
# 1691 153   3571 13    H.Indexing candidates...   110     5  6        3.714
# 1693 153   3573 13    J.Finding maximal disks... 110     5  6       42.500
# 2186 198   4654 18    H.Indexing candidates...   110     5  6        3.961
# 2188 198   4656 18    J.Finding maximal disks... 110     5  6       48.810
# 2197 199   4671 18    H.Indexing candidates...   110     5  6        3.609
# 2199 199   4673 18    J.Finding maximal disks... 110     5  6       37.460
# 2208 200   4694 18    H.Indexing candidates...   110     5  6        3.089
# 2210 200   4696 18    J.Finding maximal disks... 110     5  6       50.223
# 2219 201   4711 18    H.Indexing candidates...   110     5  6        3.188
# 2221 201   4713 18    J.Finding maximal disks... 110     5  6       37.872
# 2230 202   4734 18    H.Indexing candidates...   110     5  6        2.699
# 2232 202   4736 18    J.Finding maximal disks... 110     5  6      103.300
# 2241 203   4751 18    H.Indexing candidates...   110     5  6        3.664
# 2243 203   4753 18    J.Finding maximal disks... 110     5  6       49.907
# 2252 204   4774 18    H.Indexing candidates...   110     5  6        3.562
# 2254 204   4776 18    J.Finding maximal disks... 110     5  6      291.525
# 2263 205   4791 18    H.Indexing candidates...   110     5  6        2.811
# 2265 205   4793 18    J.Finding maximal disks... 110     5  6       28.897
# 2274 206   4814 18    H.Indexing candidates...   110     5  6        3.617
# 2276 206   4816 18    J.Finding maximal disks... 110     5  6     1525.805
# 2285 207   4831 18    H.Indexing candidates...   110     5  6        3.902
# 2287 207   4833 18    J.Finding maximal disks... 110     5  6       40.086
# 2296 208   4856 18    H.Indexing candidates...   110     5  6        3.218
# 2298 208   4858 18    J.Finding maximal disks... 110     5  6       31.841
#      Load  Timestamp
# 371  17049  0
# 373   2553  0
# 382  17870  5
# 384   2747  5
# 393  17416  1
# 395   2586  1
# 404  17770  6
# 406   2733  6
# 415  17604  2
# 417   2660  2
# 426  17722  7
# 428   2741  7
# 437  17992  3
# 439   2746  3
# 448  17675  8
# 450   2721  8
# 459  17915  4
# 461   2726  4
# 470  17594  9
# 472   2702  9
# 481  17578 10
# 483   2667 10
# 976  17049  0
# 978   2553  0
# 987  17870  5
# 989   2747  5
# 998  17416  1
# 1000  2586  1
# 1009 17770  6
# 1011  2733  6
# ⋮    ⋮     ⋮
# 1658 17675  8
# 1660  2721  8
# 1669 17915  4
# 1671  2726  4
# 1680 17594  9
# 1682  2702  9
# 1691 17578 10
# 1693  2667 10
# 2186 17049  0
# 2188  2553  0
# 2197 17870  5
# 2199  2747  5
# 2208 17416  1
# 2210  2586  1
# 2219 17770  6
# 2221  2733  6
# 2230 17604  2
# 2232  2660  2
# 2241 17722  7
# 2243  2741  7
# 2252 17992  3
# 2254  2746  3
# 2263 17675  8
# 2265  2721  8
# 2274 17915  4
# 2276  2726  4
# 2285 17594  9
# 2287  2702  9
# 2296 17578 10
# 2298  2667 10

# %%
data$Perf = data$Load / data$Time
times   = data[,c("Timestamp", "Time")]
times_s = summaryBy(data=times, Time ~ Timestamp, FUN = function(x){ c(m=mean(x),s=sd(x))})
times_s

title = "Maximal disk finding execution time by timestamp"
g = ggplot(data=times_s, aes(x=factor(Timestamp), y=Time.m, ymin = Time.m-Time.s, ymax = Time.m+Time.s)) +
  geom_bar(stat="identity", position=position_dodge(width = 0.75),width = 0.75) +
  geom_pointrange(position=position_dodge(width = 0.75)) +
  labs(title=title, y="Time(s)", x="Timestamp") 
plot(g)
# Out:
#    Timestamp Time.m     Time.s
# 1   0          49.39500   3.488480
# 2   1          49.47825   1.213846
# 3   2         108.26675   3.621249
# 4   3         215.03250  78.056142
# 5   4        1603.09025 128.694040
# 6   5          54.87525  33.799174
# 7   6          48.66650  17.649951
# 8   7          94.56650  51.953153
# 9   8          29.21525   1.444358
# 10  9          49.99725   8.684625
# 11 10          37.96600   7.091836
# plot without title

# %%
perfs   = data[,c("Timestamp", "Perf")]
perfs_s = summaryBy(data=perfs, Perf ~ Timestamp, FUN = function(x){ c(m=mean(x),s=sd(x))})
perfs_s

title = "Maximal disk finding performance by timestamp"
g = ggplot(data=perfs_s, aes(x=factor(Timestamp), y=Perf.m, ymin = Perf.m-Perf.s, ymax = Perf.m+Perf.s)) +
  geom_bar(stat="identity", position=position_dodge(width = 0.75),width = 0.75) +
  geom_pointrange(position=position_dodge(width = 0.75)) +
  labs(title=title, y="Performance (candidates/sec)", x="Timestamp") 
plot(g)
# Out:
#    Timestamp Perf.m    Perf.s
# 1   0        346.39948  23.495572
# 2   1        352.15371   8.732748
# 3   2        162.73742   5.543496
# 4   3         96.76286  49.253072
# 5   4         11.22558   0.835375
# 6   5        395.67850 152.074223
# 7   6        394.56316 108.962842
# 8   7        242.19145 133.000507
# 9   8        606.11685  30.349833
# 10  9        359.90411  62.122639
# 11 10        475.28431  87.831013
# plot without title

# %%
mdf_120 = mdf[mdf$Epsilon == 120 & (mdf$Stage == "H.Indexing candidates..." | mdf$Stage == "J.Finding maximal disks..."), ]
mdf_120

data = sqldf("SELECT mdfID, Timestamp, MAX(Time) AS Time, MAX(Load) AS Load FROM mdf_120 GROUP BY mdfID, Timestamp")
# Out:
#      mdfID n    runID Stage                      Epsilon Mu Delta Time
# 492   44   1056 4     H.Indexing candidates...   120     5  6        4.634
# 494   44   1058 4     J.Finding maximal disks... 120     5  6      169.202
# 503   45   1073 4     H.Indexing candidates...   120     5  6        4.330
# 505   45   1075 4     J.Finding maximal disks... 120     5  6     1035.161
# 514   46   1096 4     H.Indexing candidates...   120     5  6        3.416
# 516   46   1098 4     J.Finding maximal disks... 120     5  6      170.107
# 525   47   1113 4     H.Indexing candidates...   120     5  6        3.837
# 527   47   1115 4     J.Finding maximal disks... 120     5  6      213.278
# 536   48   1136 4     H.Indexing candidates...   120     5  6        3.204
# 538   48   1138 4     J.Finding maximal disks... 120     5  6      675.556
# 547   49   1153 4     H.Indexing candidates...   120     5  6        3.870
# 549   49   1155 4     J.Finding maximal disks... 120     5  6      639.390
# 558   50   1176 4     H.Indexing candidates...   120     5  6        3.891
# 560   50   1178 4     J.Finding maximal disks... 120     5  6     2274.360
# 569   51   1193 4     H.Indexing candidates...   120     5  6        3.510
# 571   51   1195 4     J.Finding maximal disks... 120     5  6      310.132
# 580   52   1216 4     H.Indexing candidates...   120     5  6        4.468
# 582   52   1218 4     J.Finding maximal disks... 120     5  6      741.751
# 591   53   1233 4     H.Indexing candidates...   120     5  6        3.393
# 593   53   1235 4     J.Finding maximal disks... 120     5  6      238.340
# 602   54   1258 4     H.Indexing candidates...   120     5  6        4.520
# 604   54   1260 4     J.Finding maximal disks... 120     5  6      833.418
# 1097  99   2341 9     H.Indexing candidates...   120     5  6        4.594
# 1099  99   2343 9     J.Finding maximal disks... 120     5  6      191.358
# 1108 100   2358 9     H.Indexing candidates...   120     5  6        4.343
# 1110 100   2360 9     J.Finding maximal disks... 120     5  6     1023.541
# 1119 101   2381 9     H.Indexing candidates...   120     5  6        2.903
# 1121 101   2383 9     J.Finding maximal disks... 120     5  6      186.364
# 1130 102   2398 9     H.Indexing candidates...   120     5  6        4.367
# 1132 102   2400 9     J.Finding maximal disks... 120     5  6      628.314
# ⋮    ⋮     ⋮    ⋮     ⋮                          ⋮       ⋮  ⋮     ⋮
# 1174 106   2478  9    H.Indexing candidates...   120     5  6        3.320
# 1176 106   2480  9    J.Finding maximal disks... 120     5  6      314.120
# 1185 107   2501  9    H.Indexing candidates...   120     5  6        3.116
# 1187 107   2503  9    J.Finding maximal disks... 120     5  6      709.268
# 1196 108   2518  9    H.Indexing candidates...   120     5  6        3.949
# 1198 108   2520  9    J.Finding maximal disks... 120     5  6      241.278
# 1207 109   2543  9    H.Indexing candidates...   120     5  6        4.796
# 1209 109   2545  9    J.Finding maximal disks... 120     5  6     1108.242
# 1702 154   3626 14    H.Indexing candidates...   120     5  6        4.678
# 1704 154   3628 14    J.Finding maximal disks... 120     5  6      158.557
# 1713 155   3643 14    H.Indexing candidates...   120     5  6        4.177
# 1715 155   3645 14    J.Finding maximal disks... 120     5  6     1073.684
# 1724 156   3666 14    H.Indexing candidates...   120     5  6        2.758
# 1726 156   3668 14    J.Finding maximal disks... 120     5  6      173.439
# 1735 157   3683 14    H.Indexing candidates...   120     5  6        4.324
# 1737 157   3685 14    J.Finding maximal disks... 120     5  6      217.889
# 1746 158   3706 14    H.Indexing candidates...   120     5  6        2.479
# 1748 158   3708 14    J.Finding maximal disks... 120     5  6      620.957
# 1757 159   3723 14    H.Indexing candidates...   120     5  6        3.958
# 1759 159   3725 14    J.Finding maximal disks... 120     5  6      220.446
# 1768 160   3746 14    H.Indexing candidates...   120     5  6        4.310
# 1770 160   3748 14    J.Finding maximal disks... 120     5  6     2277.381
# 1779 161   3763 14    H.Indexing candidates...   120     5  6        3.331
# 1781 161   3765 14    J.Finding maximal disks... 120     5  6      320.170
# 1790 162   3786 14    H.Indexing candidates...   120     5  6        3.277
# 1792 162   3788 14    J.Finding maximal disks... 120     5  6      718.625
# 1801 163   3803 14    H.Indexing candidates...   120     5  6        4.928
# 1803 163   3805 14    J.Finding maximal disks... 120     5  6      249.607
# 1812 164   3828 14    H.Indexing candidates...   120     5  6        3.464
# 1814 164   3830 14    J.Finding maximal disks... 120     5  6      383.782
#      Load  Timestamp
# 492  21531  0
# 494   3162  0
# 503  22577  5
# 505   3370  5
# 514  21936  1
# 516   3223  1
# 525  22457  6
# 527   3348  6
# 536  22218  2
# 538   3270  2
# 547  22457  7
# 549   3347  7
# 558  22662  3
# 560   3391  3
# 569  22399  8
# 571   3354  8
# 580  22653  4
# 582   3381  4
# 591  22379  9
# 593   3360  9
# 602  22315 10
# 604   3317 10
# 1097 21531  0
# 1099  3162  0
# 1108 22577  5
# 1110  3370  5
# 1119 21936  1
# 1121  3223  1
# 1130 22457  6
# 1132  3348  6
# ⋮    ⋮     ⋮
# 1174 22399  8
# 1176  3354  8
# 1185 22653  4
# 1187  3381  4
# 1196 22379  9
# 1198  3360  9
# 1207 22315 10
# 1209  3317 10
# 1702 21531  0
# 1704  3162  0
# 1713 22577  5
# 1715  3370  5
# 1724 21936  1
# 1726  3223  1
# 1735 22457  6
# 1737  3348  6
# 1746 22218  2
# 1748  3270  2
# 1757 22457  7
# 1759  3347  7
# 1768 22662  3
# 1770  3391  3
# 1779 22399  8
# 1781  3354  8
# 1790 22653  4
# 1792  3381  4
# 1801 22379  9
# 1803  3360  9
# 1812 22315 10
# 1814  3317 10

# %%
data$Perf = data$Load / data$Time
times   = data[,c("Timestamp", "Time")]
times_s = summaryBy(data=times, Time ~ Timestamp, FUN = function(x){ c(m=mean(x),s=sd(x))})
times_s

title = "Maximal disk finding execution time by timestamp"
g = ggplot(data=times_s, aes(x=factor(Timestamp), y=Time.m, ymin = Time.m-Time.s, ymax = Time.m+Time.s)) +
  geom_bar(stat="identity", position=position_dodge(width = 0.75),width = 0.75) +
  geom_pointrange(position=position_dodge(width = 0.75)) +
  labs(title=title, y="Time(s)", x="Timestamp") 
plot(g)
# Out:
#    Timestamp Time.m    Time.s
# 1   0         173.0390  16.733748
# 2   1         176.6367   8.587276
# 3   2         638.5943  32.020854
# 4   3        2282.9690  12.387402
# 5   4         723.2147  16.720798
# 6   5        1044.1287  26.246798
# 7   6         353.1603 238.301218
# 8   7         505.1367 246.682108
# 9   8         314.8073   5.054175
# 10  9         243.0750   5.844504
# 11 10         775.1473 365.728281
# plot without title

# %%
perfs   = data[,c("Timestamp", "Perf")]
perfs_s = summaryBy(data=perfs, Perf ~ Timestamp, FUN = function(x){ c(m=mean(x),s=sd(x))})
perfs_s

title = "Maximal disk finding performance by timestamp"
g = ggplot(data=perfs_s, aes(x=factor(Timestamp), y=Perf.m, ymin = Perf.m-Perf.s, ymax = Perf.m+Perf.s)) +
  geom_bar(stat="identity", position=position_dodge(width = 0.75),width = 0.75) +
  geom_pointrange(position=position_dodge(width = 0.75)) +
  labs(title=title, y="Performance (candidates/sec)", x="Timestamp") 
plot(g)
# Out:
#    Timestamp Perf.m     Perf.s
# 1   0        125.186853 11.7746806
# 2   1        124.378670  5.9107018
# 3   2         34.848816  1.6984128
# 4   3          9.926742  0.0537056
# 5   4         31.333720  0.7182271
# 6   5         21.631825  0.5377183
# 7   6         81.367474 39.5287979
# 8   7         57.082923 38.7898214
# 9   8         71.163646  1.1389880
# 10  9         92.101382  2.1927790
# 11 10         35.018587 20.3013426
# plot without title
