// %%
import $ivy.`org.vegas-viz::vegas:0.3.9`
// Out:
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/vegas_2.11-0.3.9.pom
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/vegas_2.11-0.3.9.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/vegas_2.11-0.3.9.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/vegas_2.11-0.3.9.pom
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/vegas-macros_2.11-0.3.9.pom
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/vegas-macros_2.11-0.3.9.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/vegas-macros_2.11-0.3.9.pom
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/vegas-macros_2.11-0.3.9.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/vegas-macros_2.11-0.3.9.jar
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/vegas-macros_2.11-0.3.9.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/vegas_2.11-0.3.9.jar
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/vegas_2.11-0.3.9.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/vegas-macros_2.11-0.3.9.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.9/vegas-macros_2.11-0.3.9.jar
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/vegas_2.11-0.3.9.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.9/vegas_2.11-0.3.9.jar
// import $ivy.$

// %%
import vegas._
import vegas.data.External._
// Out:
// import vegas._
//
// import vegas.data.External._

// %% [markdown]
// # A simple bar chart with embedded data.

// %%
Vegas("A simple bar chart with embedded data.").
  withData(Seq(
    Map("a" -> "A", "b" -> 28), Map("a" -> "B", "b" -> 55), Map("a" -> "C", "b" -> 43),
    Map("a" -> "D", "b" -> 91), Map("a" -> "E", "b" -> 81), Map("a" -> "F", "b" -> 53),
    Map("a" -> "G", "b" -> 19), Map("a" -> "H", "b" -> 87), Map("a" -> "I", "b" -> 52)
  )).
  encodeX("a", Ordinal).
  encodeY("b", Quantitative).
  mark(Bar).
  show
// Out:
//   <iframe id="frame-vegas-6bf2c599-8a28-44e1-a26f-835e22bf60c8" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;a&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;b&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A simple bar chart with embedded data.&quot;,
//   &quot;data&quot; : {
//     &quot;values&quot; : [
//       {
//         &quot;a&quot; : &quot;A&quot;,
//         &quot;b&quot; : 28
//       },
//       {
//         &quot;a&quot; : &quot;B&quot;,
//         &quot;b&quot; : 55
//       },
//       {
//         &quot;a&quot; : &quot;C&quot;,
//         &quot;b&quot; : 43
//       },
//       {
//         &quot;a&quot; : &quot;D&quot;,
//         &quot;b&quot; : 91
//       },
//       {
//         &quot;a&quot; : &quot;E&quot;,
//         &quot;b&quot; : 81
//       },
//       {
//         &quot;a&quot; : &quot;F&quot;,
//         &quot;b&quot; : 53
//       },
//       {
//         &quot;a&quot; : &quot;G&quot;,
//         &quot;b&quot; : 19
//       },
//       {
//         &quot;a&quot; : &quot;H&quot;,
//         &quot;b&quot; : 87
//       },
//       {
//         &quot;a&quot; : &quot;I&quot;,
//         &quot;b&quot; : 52
//       }
//     ]
//   }
// }
//    }
//    vg.embed(&quot;#vegas-6bf2c599-8a28-44e1-a26f-835e22bf60c8&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-6bf2c599-8a28-44e1-a26f-835e22bf60c8'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-6bf2c599-8a28-44e1-a26f-835e22bf60c8').get(0), 1); });
//   </script>

// %% [markdown]
// # A bar chart showing the US population distribution of age groups in 2000.

// %%
Vegas("A bar chart showing the US population distribution of age groups in 2000.").
  withURL(Population).
  mark(Bar).
  filter("datum.year == 2000").
  encodeY("age", Ordinal, scale=Scale(bandSize=17)).
  encodeX("people", Quantitative, aggregate=AggOps.Sum, axis=Axis(title="population")).
  show
// Out:
//   <iframe id="frame-vegas-648405c4-fcd7-4c32-b23f-b91c473cccbb" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;axis&quot; : {
//         &quot;title&quot; : &quot;population&quot;
//       },
//       &quot;field&quot; : &quot;people&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;sum&quot;
//     },
//     &quot;y&quot; : {
//       &quot;scale&quot; : {
//         &quot;bandSize&quot; : 17.0
//       },
//       &quot;field&quot; : &quot;age&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A bar chart showing the US population distribution of age groups in 2000.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/population.json&quot;
//   },
//   &quot;transform&quot; : {
//     &quot;filter&quot; : &quot;datum.year == 2000&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-648405c4-fcd7-4c32-b23f-b91c473cccbb&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-648405c4-fcd7-4c32-b23f-b91c473cccbb'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-648405c4-fcd7-4c32-b23f-b91c473cccbb').get(0), 1); });
//   </script>

// %%
Vegas().
  withURL(Population).
  mark(Bar).
  addTransformCalculation("gender", """datum.sex == 2 ? "Female" : "Male"""").
  filter("datum.year == 2000").
  encodeColumn("age", Ord, scale=Scale(padding=4.0), axis=Axis(orient=Orient.Bottom, axisWidth=1.0, offset= -8.0)).
  encodeY("people", Quantitative, aggregate=AggOps.Sum, axis=Axis(title="population", grid=false)).
  encodeX("gender", Nominal, scale=Scale(bandSize = 6.0), hideAxis=true).
  encodeColor("gender", Nominal, scale=Scale(rangeNominals=List("#EA98D2", "#659CCA"))).
  configFacet(cell=CellConfig(strokeWidth = 0)).
  show
// Out:
//   <iframe id="frame-vegas-3df81488-0595-4fe6-bc39-729f6e205d25" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;column&quot; : {
//       &quot;axis&quot; : {
//         &quot;orient&quot; : &quot;bottom&quot;,
//         &quot;axisWidth&quot; : 1.0,
//         &quot;offset&quot; : -8.0
//       },
//       &quot;scale&quot; : {
//         &quot;padding&quot; : 4.0
//       },
//       &quot;field&quot; : &quot;age&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;x&quot; : {
//       &quot;axis&quot; : false,
//       &quot;scale&quot; : {
//         &quot;bandSize&quot; : 6.0
//       },
//       &quot;field&quot; : &quot;gender&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;axis&quot; : {
//         &quot;title&quot; : &quot;population&quot;,
//         &quot;grid&quot; : false
//       },
//       &quot;field&quot; : &quot;people&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;sum&quot;
//     },
//     &quot;color&quot; : {
//       &quot;scale&quot; : {
//         &quot;range&quot; : [
//           &quot;#EA98D2&quot;,
//           &quot;#659CCA&quot;
//         ]
//       },
//       &quot;field&quot; : &quot;gender&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/population.json&quot;
//   },
//   &quot;transform&quot; : {
//     &quot;filter&quot; : &quot;datum.year == 2000&quot;,
//     &quot;calculate&quot; : [
//       {
//         &quot;field&quot; : &quot;gender&quot;,
//         &quot;expr&quot; : &quot;datum.sex == 2 ? \&quot;Female\&quot; : \&quot;Male\&quot;&quot;
//       }
//     ]
//   },
//   &quot;config&quot; : {
//     &quot;facet&quot; : {
//       &quot;cell&quot; : {
//         &quot;strokeWidth&quot; : 0.0
//       }
//     }
//   }
// }
//    }
//    vg.embed(&quot;#vegas-3df81488-0595-4fe6-bc39-729f6e205d25&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-3df81488-0595-4fe6-bc39-729f6e205d25'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-3df81488-0595-4fe6-bc39-729f6e205d25').get(0), 1); });
//   </script>

// %%
Vegas().
  withURL(Unemployment).
  mark(Area).
  encodeX("date", Temp, timeUnit=TimeUnit.Yearmonth, scale=Scale(nice=Nice.Month),
    axis=Axis(axisWidth=0, format="%Y", labelAngle=0)).
  encodeY("count", Quantitative, aggregate=AggOps.Sum).
  configCell(width=300, height=200).
  show
// Out:
//   <iframe id="frame-vegas-2f7087c0-6fee-4bf5-a9be-541866e2bb84" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;area&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;axis&quot; : {
//         &quot;labelAngle&quot; : 0.0,
//         &quot;format&quot; : &quot;%Y&quot;,
//         &quot;axisWidth&quot; : 0.0
//       },
//       &quot;scale&quot; : {
//         &quot;nice&quot; : &quot;month&quot;
//       },
//       &quot;field&quot; : &quot;date&quot;,
//       &quot;type&quot; : &quot;temporal&quot;,
//       &quot;timeUnit&quot; : &quot;yearmonth&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;count&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;sum&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/unemployment-across-industries.json&quot;
//   },
//   &quot;config&quot; : {
//     &quot;cell&quot; : {
//       &quot;width&quot; : 300.0,
//       &quot;height&quot; : 200.0
//     }
//   }
// }
//    }
//    vg.embed(&quot;#vegas-2f7087c0-6fee-4bf5-a9be-541866e2bb84&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-2f7087c0-6fee-4bf5-a9be-541866e2bb84'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-2f7087c0-6fee-4bf5-a9be-541866e2bb84').get(0), 1); });
//   </script>

// %%
Vegas().
  withURL(Population).
  filter("datum.year == 2000").
  addTransform("gender", "datum.sex == 2 ? \"Female\" : \"Male\"").
  mark(Bar).
  encodeY("people", Quant, AggOps.Sum, axis=Axis(title="population")).
  encodeX("age", Ord, scale=Scale(bandSize= 17)).
  encodeColor("gender", Nominal, scale=Scale(rangeNominals=List("#EA98D2", "#659CCA"))).
  configMark(stacked=StackOffset.Normalize).
  show
// Out:
//   <iframe id="frame-vegas-4881eec9-2bfb-4bcd-85da-38a672c64b42" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;scale&quot; : {
//         &quot;bandSize&quot; : 17.0
//       },
//       &quot;field&quot; : &quot;age&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;axis&quot; : {
//         &quot;title&quot; : &quot;population&quot;
//       },
//       &quot;field&quot; : &quot;people&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;sum&quot;
//     },
//     &quot;color&quot; : {
//       &quot;scale&quot; : {
//         &quot;range&quot; : [
//           &quot;#EA98D2&quot;,
//           &quot;#659CCA&quot;
//         ]
//       },
//       &quot;field&quot; : &quot;gender&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/population.json&quot;
//   },
//   &quot;transform&quot; : {
//     &quot;filter&quot; : &quot;datum.year == 2000&quot;,
//     &quot;calculate&quot; : [
//       {
//         &quot;field&quot; : &quot;gender&quot;,
//         &quot;expr&quot; : &quot;datum.sex == 2 ? \&quot;Female\&quot; : \&quot;Male\&quot;&quot;
//       }
//     ]
//   },
//   &quot;config&quot; : {
//     &quot;mark&quot; : {
//       &quot;stacked&quot; : &quot;normalize&quot;
//     }
//   }
// }
//    }
//    vg.embed(&quot;#vegas-4881eec9-2bfb-4bcd-85da-38a672c64b42&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-4881eec9-2bfb-4bcd-85da-38a672c64b42'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-4881eec9-2bfb-4bcd-85da-38a672c64b42').get(0), 1); });
//   </script>

// %% [markdown]
// # A trellis scatterplot showing Horsepower and Miles per gallons, faceted by binned values of Acceleration.

// %%
Vegas("A trellis scatterplot showing Horsepower and Miles per gallons, faceted by binned values of Acceleration.").
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quantitative).
  encodeY("Miles_per_Gallon", Quantitative).
  encodeRow("Acceleration", Quantitative, enableBin=true).
  show
// Out:
//   <iframe id="frame-vegas-53050435-f68d-4063-94e5-1874a0c96d57" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;row&quot; : {
//       &quot;field&quot; : &quot;Acceleration&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : true
//     },
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A trellis scatterplot showing Horsepower and Miles per gallons, faceted by binned values of Acceleration.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-53050435-f68d-4063-94e5-1874a0c96d57&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-53050435-f68d-4063-94e5-1874a0c96d57'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-53050435-f68d-4063-94e5-1874a0c96d57').get(0), 1); });
//   </script>

// %%
Vegas().
  withURL(Movies).
  mark(Point).
  encodeX("IMDB_Rating", Quantitative, bin=Bin(maxbins=10.0)).
  encodeY("Rotten_Tomatoes_Rating", Quantitative, bin=Bin(maxbins=10.0)).
  encodeSize(aggregate=AggOps.Count, field="*", dataType=Quantitative).
  show
// Out:
//   <iframe id="frame-vegas-bc167b64-3f6b-482c-9f88-2f9269b0015f" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;IMDB_Rating&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;maxbins&quot; : 10.0
//       }
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Rotten_Tomatoes_Rating&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;maxbins&quot; : 10.0
//       }
//     },
//     &quot;size&quot; : {
//       &quot;field&quot; : &quot;*&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;count&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/movies.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-bc167b64-3f6b-482c-9f88-2f9269b0015f&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-bc167b64-3f6b-482c-9f88-2f9269b0015f'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-bc167b64-3f6b-482c-9f88-2f9269b0015f').get(0), 1); });
//   </script>

// %%
Vegas().
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quantitative).
  encodeY("Miles_per_Gallon", Quantitative).
  encodeColor(field="Origin", dataType=Nominal).
  show
// Out:
//   <iframe id="frame-vegas-f162b214-6486-449e-a519-bc57cbb8516b" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Origin&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-f162b214-6486-449e-a519-bc57cbb8516b&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-f162b214-6486-449e-a519-bc57cbb8516b'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-f162b214-6486-449e-a519-bc57cbb8516b').get(0), 1); });
//   </script>

// %% [markdown]
// # A scatterplot showing horsepower and miles per gallons with binned acceleration on color.

// %%
Vegas("A scatterplot showing horsepower and miles per gallons with binned acceleration on color.").
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quantitative).
  encodeY("Miles_per_Gallon", Quantitative).
  encodeColor(field="Acceleration", dataType=Quantitative, bin=Bin(maxbins=5.0)).
  show
// Out:
//   <iframe id="frame-vegas-c571f6ed-224f-40b8-9e59-cc2760bd2845" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Acceleration&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;maxbins&quot; : 5.0
//       }
//     }
//   },
//   &quot;description&quot; : &quot;A scatterplot showing horsepower and miles per gallons with binned acceleration on color.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-c571f6ed-224f-40b8-9e59-cc2760bd2845&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-c571f6ed-224f-40b8-9e59-cc2760bd2845'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-c571f6ed-224f-40b8-9e59-cc2760bd2845').get(0), 1); });
//   </script>

// %%
Vegas().
  withURL(Cars).
  mark(Area).
  encodeX("Acceleration", Quantitative, bin=Bin()).
  encodeY("Horsepower", Quantitative, AggOps.Mean, enableBin=false).
  encodeColor(field="Cylinders", dataType=Nominal).
  show
// Out:
//   <iframe id="frame-vegas-7696a3c7-72d3-4803-ad96-8926ec30f79d" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;area&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Acceleration&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//
//       }
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : false,
//       &quot;aggregate&quot; : &quot;mean&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Cylinders&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-7696a3c7-72d3-4803-ad96-8926ec30f79d&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-7696a3c7-72d3-4803-ad96-8926ec30f79d'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-7696a3c7-72d3-4803-ad96-8926ec30f79d').get(0), 1); });
//   </script>

// %% [markdown]
// # The Trellis display by Becker et al. helped establish small multiples as a “powerful mechanism for understanding interactions in studies of how a response depends on explanatory variables”. Here we reproduce a trellis of Barley yields from the 1930s, complete with main-effects ordering to facilitate comparison.

// %%
Vegas("The Trellis display by Becker et al. helped establish small multiples as a “powerful mechanism for understanding interactions in studies of how a response depends on explanatory variables”. Here we reproduce a trellis of Barley yields from the 1930s, complete with main-effects ordering to facilitate comparison.").
  withURL(Barley).
  mark(Point).
  encodeRow("site", Ordinal).
  encodeX("yield", Quantitative, aggregate=AggOps.Mean).
  encodeY("variety", Ordinal, sortField=Sort("yield", AggOps.Mean), scale=Scale(bandSize = 12.0)).
  encodeColor(field="year", dataType=Nominal).
  show
// Out:
//   <iframe id="frame-vegas-01fa54ea-2420-497d-9a82-94558af01746" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;row&quot; : {
//       &quot;field&quot; : &quot;site&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;yield&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;mean&quot;
//     },
//     &quot;y&quot; : {
//       &quot;scale&quot; : {
//         &quot;bandSize&quot; : 12.0
//       },
//       &quot;sort&quot; : {
//         &quot;field&quot; : &quot;yield&quot;,
//         &quot;op&quot; : &quot;mean&quot;
//       },
//       &quot;field&quot; : &quot;variety&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;year&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;The Trellis display by Becker et al. helped establish small multiples as a “powerful mechanism for understanding interactions in studies of how a response depends on explanatory variables”. Here we reproduce a trellis of Barley yields from the 1930s, complete with main-effects ordering to facilitate comparison.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/barley.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-01fa54ea-2420-497d-9a82-94558af01746&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-01fa54ea-2420-497d-9a82-94558af01746'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-01fa54ea-2420-497d-9a82-94558af01746').get(0), 1); });
//   </script>

// %% [markdown]
// # A scatterplot with custom star shapes.

// %%
Vegas("A scatterplot with custom star shapes.").
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quant).
  encodeY("Miles_per_Gallon", Quant).
  encodeColor("Cylinders", Nom).
  encodeSize("Weight_in_lbs", Quant).
  configMark(customShape="M0,0.2L0.2351,0.3236 0.1902,0.0618 0.3804,-0.1236 0.1175,-0.1618 0,-0.4 -0.1175,-0.1618 -0.3804,-0.1236 -0.1902,0.0618 -0.2351,0.3236 0,0.2Z").
  show
// Out:
//   <iframe id="frame-vegas-934ad6c9-86ca-43c6-af69-4caa7f51e2e6" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Cylinders&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;size&quot; : {
//       &quot;field&quot; : &quot;Weight_in_lbs&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A scatterplot with custom star shapes.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   },
//   &quot;config&quot; : {
//     &quot;mark&quot; : {
//       &quot;shape&quot; : &quot;M0,0.2L0.2351,0.3236 0.1902,0.0618 0.3804,-0.1236 0.1175,-0.1618 0,-0.4 -0.1175,-0.1618 -0.3804,-0.1236 -0.1902,0.0618 -0.2351,0.3236 0,0.2Z&quot;
//     }
//   }
// }
//    }
//    vg.embed(&quot;#vegas-934ad6c9-86ca-43c6-af69-4caa7f51e2e6&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-934ad6c9-86ca-43c6-af69-4caa7f51e2e6'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-934ad6c9-86ca-43c6-af69-4caa7f51e2e6').get(0), 1); });
//   </script>

// %% [markdown]
// # A scatterplot showing average horsepower and displacement for cars from different origins.

// %%
Vegas("A scatterplot showing average horsepower and displacement for cars from different origins.").
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quant, AggOps.Mean).
  encodeY("Displacement", Quant, AggOps.Mean).
  encodeDetail("Origin").
  show
// Out:
//   <iframe id="frame-vegas-db5099b4-0c97-4a49-8217-6b0faf53cbe5" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;mean&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Displacement&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;mean&quot;
//     },
//     &quot;detail&quot; : {
//       &quot;field&quot; : &quot;Origin&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A scatterplot showing average horsepower and displacement for cars from different origins.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-db5099b4-0c97-4a49-8217-6b0faf53cbe5&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-db5099b4-0c97-4a49-8217-6b0faf53cbe5'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-db5099b4-0c97-4a49-8217-6b0faf53cbe5').get(0), 1); });
//   </script>

// %% [markdown]
// # Stock prices of 5 Tech Companies Over Time.

// %%
Vegas("Stock prices of 5 Tech Companies Over Time.").
  withURL(Stocks, formatType = DataFormat.Csv).
  mark(Line).
  encodeX("date", Temp).
  encodeY("price", Quant).
  encodeDetailFields(Field(field="symbol", dataType=Nominal)).
  show
// Out:
//   <iframe id="frame-vegas-08a8e480-28ff-4c25-893d-18f4e29807e8" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;line&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;date&quot;,
//       &quot;type&quot; : &quot;temporal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;price&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;detail&quot; : {
//       &quot;field&quot; : &quot;symbol&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Stock prices of 5 Tech Companies Over Time.&quot;,
//   &quot;data&quot; : {
//     &quot;format&quot; : {
//       &quot;type&quot; : &quot;csv&quot;
//     },
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/stocks.csv&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-08a8e480-28ff-4c25-893d-18f4e29807e8&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-08a8e480-28ff-4c25-893d-18f4e29807e8'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-08a8e480-28ff-4c25-893d-18f4e29807e8').get(0), 1); });
//   </script>

// %% [markdown]
// # Plot with hard-coded size value

// %%
Vegas("Plot with hard-coded size value").
  withURL(Cars).
  mark(Circle).
  encodeY("Horsepower", Quantitative).
  encodeX("Miles_per_Gallon", Quantitative).
  encodeSize(value=201L).
  show
// Out:
//   <iframe id="frame-vegas-e39ca745-b7c7-405d-ae03-5100cda8e1db" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;circle&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;size&quot; : {
//       &quot;value&quot; : 201.0
//     }
//   },
//   &quot;description&quot; : &quot;Plot with hard-coded size value&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-e39ca745-b7c7-405d-ae03-5100cda8e1db&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-e39ca745-b7c7-405d-ae03-5100cda8e1db'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-e39ca745-b7c7-405d-ae03-5100cda8e1db').get(0), 1); });
//   </script>

// %% [markdown]
// # Plots both mean and IQR as a background layer

// %%
Vegas.layered("Plots both mean and IQR as a background layer").
  withURL(Population).
  withLayers(
    Layer().
      mark(Line).
      encodeX("age", Ordinal).
      encodeY("people", aggregate=AggOps.Mean),
    Layer().
      mark(Area).
      encodeX("age", Ordinal).
      encodeY("people", aggregate=AggOps.Q1).
      encodeY2("people", aggregate=AggOps.Q3)
  ).
  show
// Out:
//   <iframe id="frame-vegas-3ad5e5eb-007b-4066-9666-b061ec4eedd5" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;layers&quot; : [
//     {
//       &quot;mark&quot; : &quot;line&quot;,
//       &quot;encoding&quot; : {
//         &quot;x&quot; : {
//           &quot;field&quot; : &quot;age&quot;,
//           &quot;type&quot; : &quot;ordinal&quot;
//         },
//         &quot;y&quot; : {
//           &quot;field&quot; : &quot;people&quot;,
//           &quot;aggregate&quot; : &quot;mean&quot;
//         }
//       }
//     },
//     {
//       &quot;mark&quot; : &quot;area&quot;,
//       &quot;encoding&quot; : {
//         &quot;x&quot; : {
//           &quot;field&quot; : &quot;age&quot;,
//           &quot;type&quot; : &quot;ordinal&quot;
//         },
//         &quot;y&quot; : {
//           &quot;field&quot; : &quot;people&quot;,
//           &quot;aggregate&quot; : &quot;q1&quot;
//         },
//         &quot;y2&quot; : {
//           &quot;field&quot; : &quot;people&quot;,
//           &quot;aggregate&quot; : &quot;q3&quot;
//         }
//       }
//     }
//   ],
//   &quot;description&quot; : &quot;Plots both mean and IQR as a background layer&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/population.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-3ad5e5eb-007b-4066-9666-b061ec4eedd5&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-3ad5e5eb-007b-4066-9666-b061ec4eedd5'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-3ad5e5eb-007b-4066-9666-b061ec4eedd5').get(0), 1); });
//   </script>

// %% [markdown]
// # Plot with legend on the left and a different title

// %%
Vegas("Plot with legend on the left and a different title ").
  withURL(Cars).
  mark(Point).
  encodeY("Horsepower", Quantitative).
  encodeX("Miles_per_Gallon", Quantitative).
  encodeColor(field="Origin", dataType=Nominal, legend=Legend(orient = "left", title="Place of Origin" )).
  encodeShape(field="Origin", dataType=Nominal, legend=Legend(orient = "left", title="Place of Origin",
    titleColor="red")).
  show
// Out:
//   <iframe id="frame-vegas-da1a73ef-f6de-4103-b3a8-9c33bcb2cc27" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;legend&quot; : {
//         &quot;title&quot; : &quot;Place of Origin&quot;,
//         &quot;orient&quot; : &quot;left&quot;
//       },
//       &quot;field&quot; : &quot;Origin&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;shape&quot; : {
//       &quot;legend&quot; : {
//         &quot;title&quot; : &quot;Place of Origin&quot;,
//         &quot;orient&quot; : &quot;left&quot;,
//         &quot;titleColor&quot; : &quot;red&quot;
//       },
//       &quot;field&quot; : &quot;Origin&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Plot with legend on the left and a different title &quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-da1a73ef-f6de-4103-b3a8-9c33bcb2cc27&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-da1a73ef-f6de-4103-b3a8-9c33bcb2cc27'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-da1a73ef-f6de-4103-b3a8-9c33bcb2cc27').get(0), 1); });
//   </script>

// %% [markdown]
// # Plot to show Binning options

// %%
Vegas("Plot to show Binning options").
  withURL(Movies).
  mark(Bar).
  encodeX("IMDB_Rating", Quantitative, bin=Bin(step=2.0, maxbins=3.0)).
  encodeY(field="*", Quantitative, aggregate=AggOps.Count).
  show
// Out:
//   <iframe id="frame-vegas-54eb216f-6efa-4cdc-892f-540bf1e6676a" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;IMDB_Rating&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;step&quot; : 2.0,
//         &quot;maxbins&quot; : 3.0
//       }
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;*&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;count&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Plot to show Binning options&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/movies.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-54eb216f-6efa-4cdc-892f-540bf1e6676a&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//  &lt;div id='vegas-54eb216f-6efa-4cdc-892f-540bf1e6676a'&gt;&lt;/div&gt;
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     if (typeof resizeIFrame != 'function') {
//       function resizeIFrame(el, k) {
//         $(el.contentWindow.document).ready(function() {
//           el.style.height = el.contentWindow.document.body.scrollHeight + 'px';
//         });
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//     }
//     $().ready( function() { resizeIFrame($('#frame-vegas-54eb216f-6efa-4cdc-892f-540bf1e6676a').get(0), 1); });
//   </script>

// %% [markdown]
// # Plot to show Binning options

// %%
Vegas("Plot to show Binning options").
  withURL(Movies).
  mark(Bar).
  encodeX("Worldwide_Gross", Quant, bin=Bin(maxbins=20.0), sortOrder=SortOrder.Desc).
  encodeY(field="*", Quant, aggregate=AggOps.Count).
  show

// %% [markdown]
// # Plot to show usage of encodeText

// %%
Vegas("Plot to show usage of encodeText").
  withURL(Cars).
  addTransform("OriginInitial", "datum.Origin[0]").
  mark(Text).
  encodeX("Horsepower", Quantitative).
  encodeY("Miles_per_Gallon", Quantitative).
  encodeColor(field="Origin", dataType= Nominal).
  encodeText(field="OriginInitial", dataType= Nominal).
  show
